# %%
import sys
import torch
import ultralytics
import cv2

print("--- 환경 세팅 검증 ---") 
print("Python 버전:", sys.version.split()[0])
print("PyTorch 버전:", torch.__version__) 
print("GPU 사용 가능 여부:", torch.cuda.is_available()) 
if torch.cuda.is_available(): print("사용 중인 GPU 이름:", torch.cuda.get_device_name(0)) 
print("Ultralytics(YOLOv11) 버전:", ultralytics.__version__) 
print("OpenCV 버전:", cv2.__version__)
# Out:
# --- 환경 세팅 검증 ---
# Python 버전: 3.11.15
# PyTorch 버전: 2.6.0+cu124
# GPU 사용 가능 여부: True
# 사용 중인 GPU 이름: NVIDIA GeForce RTX 4060
# Ultralytics(YOLOv11) 버전: 8.4.109
# OpenCV 버전: 5.0.0
