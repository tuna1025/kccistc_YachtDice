# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.13.0+cpu
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 import torch
#       2
#       3 print(torch.__version__)
#       4 print(torch.cuda.is_available())
# ----> 5 print(torch.cuda.get_device_name(0))
#
# File c:\ProgramData\anaconda3\envs\yacht_env\Lib\site-packages\torch\cuda\__init__.py:704, in get_device_name(device)
#     692 def get_device_name(device: Device = None) -> str:
#     693     r"""Get the name of a device.
#     694
#     695     Args:
#    (...)    702         str: the name of the device
#     703     """
# --> 704     return get_device_properties(device).name
#
# File c:\ProgramData\anaconda3\envs\yacht_env\Lib\site-packages\torch\cuda\__init__.py:737, in get_device_properties(device)
#     725 def get_device_properties(device: Device = None) -> _CudaDeviceProperties:
# ...
